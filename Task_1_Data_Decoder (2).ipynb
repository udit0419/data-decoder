# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6a511c9b-dfd2-49df-a452-14114b901d7d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6a511c9b-dfd2-49df-a452-14114b901d7d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("fifa21_male2.csv")  # now it should work
df.head()
# Out:
# /tmp/ipython-input-2-2085870968.py:3: DtypeWarning: Columns (78) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("fifa21_male2.csv")  # now it should work
#    ID         Name  Age  OVA            Nationality           Club  BOV   BP  \
# 0   2  G. Pasquale   33   69                  Italy        Udinese   71  LWB
# 1  16  Luis García   37   71                  Spain      KAS Eupen   70   CM
# 2  27      J. Cole   33   71                England  Coventry City   71  CAM
# 3  36     D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70   ST
# 4  41      Iniesta   36   81                  Spain    Vissel Kobe   82  CAM
#
#        Position                                       Player Photo  ...  \
# 0            LM  https://cdn.sofifa.com/players/000/002/16_120.png  ...
# 1    CM CAM CDM  https://cdn.sofifa.com/players/000/016/19_120.png  ...
# 2  CAM RM RW LM  https://cdn.sofifa.com/players/000/027/16_120.png  ...
# ...

# %%
print("First 10 Rows:")
print(df.head(10))
# Out:
# First 10 Rows:
#     ID           Name  Age  OVA            Nationality               Club  \
# 0    2    G. Pasquale   33   69                  Italy            Udinese
# 1   16    Luis García   37   71                  Spain          KAS Eupen
# 2   27        J. Cole   33   71                England      Coventry City
# 3   36       D. Yorke   36   68  Trinidad &amp; Tobago         Sunderland
# 4   41        Iniesta   36   81                  Spain        Vissel Kobe
# 5   61     D. Odonkor   27   66                Germany   Alemannia Aachen
# 6   80   E. Belözoğlu   38   77                 Turkey      Fenerbahçe SK
# 7  241       R. Giggs   39   78                  Wales  Manchester United
# 8  244  G. Neville  B   35   76                England  Manchester United
# 9  246     P. Scholes   37   80                England  Manchester United
#
#    BOV   BP      Position                                       Player Photo  \
# ...

# %%
print("\nColumn Names and Data Types:")
print(df.dtypes)
# Out:
# Column Names and Data Types:
# ID              int64
# Name           object
# Age             int64
# OVA             int64
# Nationality    object
#                 ...
# CB             object
# RCB            object
# RB             object
# GK             object
# Gender         object
# Length: 107, dtype: object

# %%
print("\nMissing Values in Each Column:")
print(df.isnull().sum())
# Out:
# Missing Values in Each Column:
# ID             0
# Name           0
# Age            0
# OVA            0
# Nationality    0
#               ..
# CB             0
# RCB            0
# RB             0
# GK             0
# Gender         0
# Length: 107, dtype: int64

# %%
print("\nStatistics for 'Age':")
print("Mean:", df['Age'].mean())
print("Median:", df['Age'].median())
print("Min:", df['Age'].min())
print("Max:", df['Age'].max())

print("\nStatistics for 'score':")
print("Mean:", df['OVA'].mean())
print("Median:", df['OVA'].median())
print("Min:", df['OVA'].min())
print("Max:", df['OVA'].max())
# Out:
# Statistics for 'Age':
# Mean: 25.272934306569343
# Median: 25.0
# Min: 16
# Max: 53
#
# Statistics for 'score':
# Mean: 66.96502189781022
# Median: 67.0
# Min: 38
# Max: 93

# %% [markdown]
# we can see that this dataset inclides player's name, age, nationality, and more. There also coulmns with abbreviated headers, such as OVA, POT, CDM, and more.
#
# When describing the FIFA 21 dataset, we find out that it has 17,125 columns and most of columns have zero missing values, which will simplify the data preparation process. Also discover
#
# The youngest player is 16 years old.
# the oldest player is 53 years old.
#
# The lowest overall player's score is 38 and the highest is 93.
